# %% [markdown]
# The Dataset Used can also be found through Kaggle<br>
# https://www.kaggle.com/datasets/camnugent/california-housing-prices

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(context="notebook",style="whitegrid")
# Out:
# C:\Users\Lenovo\anaconda3\envs\dataml100\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
californiaHousingDf = pd.read_csv("C:/Users/Lenovo/Desktop/My Git Repo/DataScienceGuide/DataScienceGuide/DataSets/housing.csv")

# %%
californiaHousingDf
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# ### Explore Data Analysis

# %%
californiaHousingDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
californiaHousingDf.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
californiaHousingDf["ocean_proximity"].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
for column in californiaHousingDf.columns:
    print("Column Name: ",column, californiaHousingDf[column].isna().unique())
# Out:
# Column Name:  longitude [False]
# Column Name:  latitude [False]
# Column Name:  housing_median_age [False]
# Column Name:  total_rooms [False]
# Column Name:  total_bedrooms [False  True]
# Column Name:  population [False]
# Column Name:  households [False]
# Column Name:  median_income [False]
# Column Name:  median_house_value [False]
# Column Name:  ocean_proximity [False]

# %%
sns.distplot(californiaHousingDf["total_bedrooms"],kde=False)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17064\2623921476.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(californiaHousingDf["total_bedrooms"],kde=False)
# <Axes: xlabel='total_bedrooms'>

# %%
#Now either you can give median for NAN values or through Distribution plot and further analysis find out which value will be better.
californiaHousingDf["total_bedrooms"].fillna(value=californiaHousingDf["total_bedrooms"].mean(),inplace=True)

# %%
sns.distplot(californiaHousingDf["total_bedrooms"],kde=False)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17064\2623921476.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(californiaHousingDf["total_bedrooms"],kde=False)
# <Axes: xlabel='total_bedrooms'>

# %%
def MakingCategoriesVisible(oceanProximity):
    if "land" in str.lower(oceanProximity):
        return 0
    else:
        return 1

# %%
#As Column is category so apllying on each category
californiaHousingDf["ocean_proximity_num"]=californiaHousingDf["ocean_proximity"].apply(lambda row: MakingCategoriesVisible(row))

# %%
print("Number of Unique elements in New Categorical Variable is ",californiaHousingDf["ocean_proximity_num"].unique())
# Out:
# Number of Unique elements in New Categorical Variable is  [1 0]

# %%
sns.boxplot(y="median_house_value",data=californiaHousingDf,hue="ocean_proximity_num")
plt.legend(title="ocean_proximity_num", bbox_to_anchor=(1.05, 1), loc='upper left')

# %%
sns.jointplot(x="total_bedrooms",y="total_bedrooms",data=californiaHousingDf,hue="ocean_proximity_num")

# %%
sns.violinplot(x="median_house_value",data=californiaHousingDf)
# Out:
# <Axes: xlabel='median_house_value'>

# %%
sns.heatmap(californiaHousingDf.corr(),cmap="coolwarm",annot=True)
# Out:
# <Axes: >

# %%
sns.lmplot(x="median_income",y="median_house_value",data=californiaHousingDf)

# %% [markdown]
# ### Model Building

# %%
#Split Data
X_Data=californiaHousingDf[['longitude','latitude','housing_median_age','total_rooms','total_bedrooms','population','households','median_income','ocean_proximity_num']]
Y_Data=californiaHousingDf["median_house_value"]

# %% [markdown]
# The proportion of data split between the training set and the test set is a crucial decision when using the train-test split method for model evaluation in machine learning. The most common split ratios are 70-30, 80-20, or 75-25, but the choice depends on factors such as the size of your dataset, the complexity of your model, and the specific goals of your analysis.

# %%
#Here I am allocating 33 percent as Test Data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_Data, Y_Data, test_size=0.33, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
Model = LinearRegression()

# %%
#Trained My Model
Model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print("It represents the estimated value of the target variable when all features are zero", Model.intercept_)
print(Model.coef_)
# Out:
# It represents the estimated value of the target variable when all features are zero -2356690.412794298
# [-2.76734569e+04 -2.69356942e+04  1.06502202e+03 -3.87351651e+00
#   7.00761489e+01 -4.47992500e+01  8.85131170e+01  3.85874623e+04
#   3.85085534e+04]

# %%
Coeff_Frame = pd.DataFrame(data=Model.coef_,index=X_train.columns,columns=['Coeff'] )
Coeff_Frame
# Out:
#                             Coeff
# longitude           -27673.456907
# latitude            -26935.694239
# housing_median_age    1065.022015
# total_rooms             -3.873517
# total_bedrooms          70.076149
# population             -44.799250
# households              88.513117
# median_income        38587.462293
# ocean_proximity_num  38508.553403

# %% [markdown]
# #### Predictions

# %%
Predictions = Model.predict(X_test)

# %%
Predictions
# Out:
# array([317018.32637027, 538143.84899831, 162633.61959515, ...,
#        284848.99539864, 288912.2513875 , 115593.27862267])

# %%
#To visualize if we had made a starigth line model
plt.scatter(y_test,Predictions)
plt.show()

# %% [markdown]
# Let's Make Histogram of Residuals to see more clearly our Model picture.  Residuals are difference betwen Actual Value and Prediction Values.
# If Normally Distributed Residuals then Linear Model is a correct choice.

# %%
sns.distplot(x=y_test-Predictions)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17064\985937519.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=y_test-Predictions)
# <Axes: ylabel='Density'>

# %% [markdown]
# #### Regresion Evaluation Metrics

# %% [markdown]
# The loss function quantifies how well the model's predictions match the actual target values. It measures the "loss" or error between the predicted values and the true values, providing a measure of how far off the model's predictions are from the actual outcomes.<br>
# If prediction accuracy is crucial, Then in Regression task MSE or RMSE may be more appropriate.Now lets calculate loss function or efficiency of our model.

# %%
from sklearn import metrics
def printModelAccuracy(y_test,p):
    #Mean Absolute Error
    print("MAE: ",metrics.mean_absolute_error(y_test,p))
    #Mean Square Error, More popular as it punishes larger error, as it squares.
    print("MSE: ",metrics.mean_squared_error(y_test,p))
    #Square Root Mean square Error
    print("RMSE: ",np.sqrt(metrics.mean_squared_error(y_test,p)))
    #Goodness of a Linear Fit from 0 to 1, but there is chance of higher value with more independent variables, in that case see Adjusted R-sQUARE
    print("R-Square: ",metrics.r2_score(y_test,p))

# %%
printModelAccuracy(y_test,Predictions)
# Out:
# MAE:  50868.34381125483
# MSE:  5016549070.220125
# RMSE:  70827.60104803865
# R-Square:  0.6267297084555363

# %% [markdown]
# Improvement can be done through<br>
# 1- Feature Engineering<br>
# 2- Scaling Features<br>
# 3- Complex Models<br>
# 4- Handling Outliers<br>
# 5-Regularization<br>
