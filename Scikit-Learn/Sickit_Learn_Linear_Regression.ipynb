# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
import seaborn as sns

# %%
boston_data  = load_boston()
#As it is a dictionary so check it through
#boston_data
print(boston_data.keys())
#print(boston_data.data.shape)
#print(boston_data.feature_names)
#print(boston_data.DESCR)
#df = pd.DataFrame(data=boston_data)
#df.head()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
#bos = pd.DataFrame(boston_data.data)
#bos.columns = boston_data.feature_names
#Or as both way are same
bos = pd.DataFrame(data=boston_data.data,columns = boston_data.feature_names)

print(bos.head())
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
#Adding Label column in Dataframe
bos['Price'] = boston_data.target
bos
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Price
# 0       15.3  396.90   4.98   24.0
# ...

# %%
bos.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'Price'],
#       dtype='object')

# %%
X_Data = bos[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT']]
#X_Data
Y_Data = bos['Price']
#Y_Data

# %%
X_Data.info()
X_Data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
# dtypes: float64(13)
# memory usage: 51.5 KB
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_Data, Y_Data, test_size=0.33, random_state=101)

# %%
from sklearn.linear_model import LinearRegression
Model = LinearRegression()

# %%
#Trained My Model
Model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(Model.intercept_)
print(Model.coef_)
# Out:
# 41.54823828095554
# [-8.68244613e-02  4.34533817e-02  4.06479957e-02  3.18620329e+00
#  -1.77223413e+01  3.06720110e+00  1.03514129e-02 -1.31554107e+00
#   2.64955135e-01 -1.12011608e-02 -9.74579422e-01  5.92604311e-03
#  -5.83927982e-01]

# %%
Coeff_Frame = pd.DataFrame(data=Model.coef_,index=X_train.columns,columns=['Coeff'] )
Coeff_Frame
# Out:
#              Coeff
# CRIM     -0.086824
# ZN        0.043453
# INDUS     0.040648
# CHAS      3.186203
# NOX     -17.722341
# RM        3.067201
# AGE       0.010351
# DIS      -1.315541
# RAD       0.264955
# TAX      -0.011201
# PTRATIO  -0.974579
# B         0.005926
# LSTAT    -0.583928

# %%
Predictions = Model.predict(X_test)

# %%
#To visualize if we had made a starigth line model
plt.scatter(y_test,Predictions)
plt.show()

# %%
#Now lets calculate loss function or efficiency of our model 
from sklearn import metrics
#Mean Absolute Error
print(metrics.mean_absolute_error(y_test,Predictions))
#Mean Square Error
print(metrics.mean_squared_error(y_test,Predictions))
#Square Root Mean square Error
print(np.sqrt(metrics.mean_squared_error(y_test,Predictions)))
# Out:
# 3.80852062174587
# 28.883441830917157
# 5.374331756685398
