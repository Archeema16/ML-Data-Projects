# %% [markdown]
# You can also get the dataset from
# https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
# Out:
# C:\Users\Lenovo\anaconda3\envs\dataml100\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from sklearn.datasets import load_breast_cancer
breast_cancer  = load_breast_cancer()

# %%
print(breast_cancer.keys())
print(breast_cancer.target_names)
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])
# ['malignant' 'benign']

# %%
df = pd.DataFrame(data = breast_cancer['data'],columns = breast_cancer['feature_names'])
df["Target"] = breast_cancer["target"]

# %%
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %% [markdown]
# #### Exploratory Data Analysis

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
plt.figure(figsize=(18,12))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
for column in df.columns:
    print(column, " Null Value count:",sum(df[column].isna()))
# Out:
# mean radius  Null Value count: 0
# mean texture  Null Value count: 0
# mean perimeter  Null Value count: 0
# mean area  Null Value count: 0
# mean smoothness  Null Value count: 0
# mean compactness  Null Value count: 0
# mean concavity  Null Value count: 0
# mean concave points  Null Value count: 0
# mean symmetry  Null Value count: 0
# mean fractal dimension  Null Value count: 0
# radius error  Null Value count: 0
# texture error  Null Value count: 0
# perimeter error  Null Value count: 0
# area error  Null Value count: 0
# smoothness error  Null Value count: 0
# compactness error  Null Value count: 0
# concavity error  Null Value count: 0
# concave points error  Null Value count: 0
# symmetry error  Null Value count: 0
# fractal dimension error  Null Value count: 0
# worst radius  Null Value count: 0
# worst texture  Null Value count: 0
# worst perimeter  Null Value count: 0
# worst area  Null Value count: 0
# worst smoothness  Null Value count: 0
# ...

# %%
sns.countplot(x=df["Target"])
# Out:
# <Axes: xlabel='Target', ylabel='count'>

# %% [markdown]
# #### Model Building

# %%
X_Data = df.drop("Target",axis=1)
Y_Data = df["Target"]
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X_Data,Y_Data,test_size=0.30,random_state=101)

# %%
print(X_train.shape,y_test.shape)
# Out:
# (398, 30) (171,)

# %%
from sklearn.svm import SVC
SVModel = SVC()

# %%
SVModel.get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
#Here default parameters are used for SVM which is not good practice
SVModel.fit(X_train,y_train)
# Out:
# SVC()

# %%
predictions = SVModel.predict(X_test)
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
print(classification_report(y_test,predictions))
print(confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.85      0.90        66
#            1       0.91      0.97      0.94       105
#
#     accuracy                           0.92       171
#    macro avg       0.93      0.91      0.92       171
# weighted avg       0.93      0.92      0.92       171
#
# [[ 56  10]
#  [  3 102]]

# %% [markdown]
# Remember C parameter is for deciding if you want soft margin or hard margin. <br>
# High C parameter is for deciding to go with hard margin(less margin distance as well) and have leat to no missclassification <br>
# Low C parameter is for deciding to go with soft margin(more margin distance as well) and have missclassification <br><br>
# Remember kernel parameter in svm helps in separating data by coverting it into higher dimesnion, Linear seaparates data on linear level, rbf, ploynomial on non-linear level<br>
# As the Support Vector Machine has many parameters to tune, so finding the best match according to your automately can be done by using GridSearchCV.<br>

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={'C':[0.1,10],'gamma':[1.0,0.0001],'kernel':['linear', 'poly', 'rbf']}

# %%
grid = GridSearchCV(SVC(),param_grid,verbose=2)

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END ....................C=0.1, gamma=1.0, kernel=linear; total time=   0.0s
# [CV] END ....................C=0.1, gamma=1.0, kernel=linear; total time=   0.0s
# [CV] END ....................C=0.1, gamma=1.0, kernel=linear; total time=   0.0s
# [CV] END ....................C=0.1, gamma=1.0, kernel=linear; total time=   0.0s
# [CV] END ....................C=0.1, gamma=1.0, kernel=linear; total time=   0.0s
# [CV] END ......................C=0.1, gamma=1.0, kernel=poly; total time=  28.0s
# [CV] END ......................C=0.1, gamma=1.0, kernel=poly; total time=   7.4s
# [CV] END ......................C=0.1, gamma=1.0, kernel=poly; total time=  29.8s

# %%
grid.best_params_

# %%
grid.best_estimator_

# %%
grid_predictions = grid.predict(X_test)
print(classification_report(y_test,predictions))
print(confusion_matrix(y_test,predictions))
